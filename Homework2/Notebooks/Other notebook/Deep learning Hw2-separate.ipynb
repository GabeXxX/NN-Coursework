# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/
# %ls
# Out:
# /gdrive/MyDrive
#  AuroregressiveForecasting/            IncpetionFtAugWeighModel1_more_layer/
#  AuroregressiveForecasting48/          IncpetionFtModel1/
#  AuroregressiveLOUGATTForecasting48/   IncpetionModel1/
#  AuroregressivePREATTForecasting48/    model_plot.png
# 'Colab Notebooks'/                     model.png
#  Dataset/                              S3CRET/
#  FinalModel/                           SimpleLSTMForecasting/
#  Gabriele/                             SimplerModel/
#  IncpetionFtAugModel1/                 StandardModel/
#  IncpetionFtAugWeighModel1/            training/

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
import math
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset = pd.read_csv('Dataset/Training.csv')
print(dataset.shape)
dataset.head()
# Out:
# (68528, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
crunch_data = pd.DataFrame(dataset['Crunchiness'])

# %%
def inspect_dataframe(df, columns, zoom):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col][1:zoom])
        axs[i].set_title(col)
    plt.show()

# %%
VALIDATION_SPLIT = 0.1

# %%
val_size = int(len(crunch_data)*VALIDATION_SPLIT)
X_train_raw = crunch_data.iloc[:-val_size]
X_val_raw = crunch_data.iloc[-val_size:]
print(X_train_raw.shape, X_val_raw.shape)

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()
print(X_min)
print(X_max)

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_val_raw-X_min)/(X_max-X_min)
# Out:
# (61676, 1) (6852, 1)
# Crunchiness   -34.802881
# dtype: float64
# Crunchiness    41.138801
# dtype: float64

# %%
def build_sequences(df, target_labels, window=2000, stride=20, telescope=864): #1156/4 = 288 time-steps into the future
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float32')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
target_labels = crunch_data.columns

# %%
TELESCOPE = 864
WINDOWS_LENGTH = 2000
STRIDE = 10
#REG_TELESCOPE = 864/TELESCOPE

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, WINDOWS_LENGTH, STRIDE, TELESCOPE)
X_test, y_test = build_sequences(X_test_raw, target_labels, WINDOWS_LENGTH, STRIDE, TELESCOPE)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((5914, 2000, 1), (5914, 864, 1), (514, 2000, 1), (514, 864, 1))

# %%
single_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.LSTM(32, return_sequences=False),
    # Shape => [batch, out_steps*features].
    tf.keras.layers.Dense(TELESCOPE,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([TELESCOPE])
])

single_lstm_model.compile(loss=tf.losses.MeanSquaredError(),
                      metrics=[tf.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError()])

# %%
epochs= 200
history_6 = single_lstm_model.fit(
    x = X_train,
    y = y_train,
    batch_size = 64,
    epochs = epochs,
    shuffle = False,
    validation_data=(X_test, y_test),
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 93/93 [==============================] - 75s 780ms/step - loss: 0.0654 - mean_absolute_error: 0.1711 - root_mean_squared_error: 0.2557 - val_loss: 0.0377 - val_mean_absolute_error: 0.1539 - val_root_mean_squared_error: 0.1943 - lr: 0.0010
# Epoch 2/200
# 93/93 [==============================] - 72s 775ms/step - loss: 0.0200 - mean_absolute_error: 0.1033 - root_mean_squared_error: 0.1414 - val_loss: 0.0377 - val_mean_absolute_error: 0.1538 - val_root_mean_squared_error: 0.1942 - lr: 0.0010
# Epoch 3/200
# 93/93 [==============================] - 72s 776ms/step - loss: 0.0200 - mean_absolute_error: 0.1033 - root_mean_squared_error: 0.1414 - val_loss: 0.0376 - val_mean_absolute_error: 0.1537 - val_root_mean_squared_error: 0.1940 - lr: 0.0010
# Epoch 4/200
# 93/93 [==============================] - 74s 791ms/step - loss: 0.0199 - mean_absolute_error: 0.1032 - root_mean_squared_error: 0.1412 - val_loss: 0.0374 - val_mean_absolute_error: 0.1531 - val_root_mean_squared_error: 0.1934 - lr: 0.0010
# Epoch 5/200
# 93/93 [==============================] - 72s 779ms/step - loss: 0.0197 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1403 - val_loss: 0.0358 - val_mean_absolute_error: 0.1483 - val_root_mean_squared_error: 0.1893 - lr: 0.0010
# Epoch 6/200
# 93/93 [==============================] - 72s 775ms/step - loss: 0.0183 - mean_absolute_error: 0.0986 - root_mean_squared_error: 0.1353 - val_loss: 0.0295 - val_mean_absolute_error: 0.1354 - val_root_mean_squared_error: 0.1718 - lr: 0.0010
# Epoch 7/200
# 93/93 [==============================] - 72s 774ms/step - loss: 0.0158 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1259 - val_loss: 0.0373 - val_mean_absolute_error: 0.1523 - val_root_mean_squared_error: 0.1930 - lr: 0.0010
# Epoch 8/200
# 93/93 [==============================] - 72s 775ms/step - loss: 0.0164 - mean_absolute_error: 0.0939 - root_mean_squared_error: 0.1282 - val_loss: 0.0206 - val_mean_absolute_error: 0.1098 - val_root_mean_squared_error: 0.1436 - lr: 0.0010
# Epoch 9/200
# 93/93 [==============================] - 72s 774ms/step - loss: 0.0147 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1212 - val_loss: 0.0199 - val_mean_absolute_error: 0.1077 - val_root_mean_squared_error: 0.1411 - lr: 0.0010
# Epoch 10/200
# 93/93 [==============================] - 72s 773ms/step - loss: 0.0142 - mean_absolute_error: 0.0860 - root_mean_squared_error: 0.1190 - val_loss: 0.0189 - val_mean_absolute_error: 0.1039 - val_root_mean_squared_error: 0.1376 - lr: 0.0010
# Epoch 11/200
# 93/93 [==============================] - 72s 777ms/step - loss: 0.0134 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1159 - val_loss: 0.0185 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1361 - lr: 0.0010
# Epoch 12/200
# 93/93 [==============================] - 72s 771ms/step - loss: 0.0131 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1146 - val_loss: 0.0184 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1356 - lr: 0.0010
# Epoch 13/200
# 93/93 [==============================] - 72s 773ms/step - loss: 0.0139 - mean_absolute_error: 0.0851 - root_mean_squared_error: 0.1178 - val_loss: 0.0212 - val_mean_absolute_error: 0.1112 - val_root_mean_squared_error: 0.1455 - lr: 0.0010
# Epoch 14/200
# 93/93 [==============================] - 72s 772ms/step - loss: 0.0128 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1133 - val_loss: 0.0175 - val_mean_absolute_error: 0.0998 - val_root_mean_squared_error: 0.1324 - lr: 0.0010
# Epoch 15/200
# 93/93 [==============================] - 72s 772ms/step - loss: 0.0125 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1119 - val_loss: 0.0172 - val_mean_absolute_error: 0.0988 - val_root_mean_squared_error: 0.1311 - lr: 0.0010
# Epoch 16/200
# 93/93 [==============================] - 72s 770ms/step - loss: 0.0134 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1156 - val_loss: 0.0170 - val_mean_absolute_error: 0.0984 - val_root_mean_squared_error: 0.1305 - lr: 0.0010
# Epoch 17/200
# 93/93 [==============================] - 71s 769ms/step - loss: 0.0124 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1112 - val_loss: 0.0166 - val_mean_absolute_error: 0.0970 - val_root_mean_squared_error: 0.1288 - lr: 0.0010
# Epoch 18/200
# 93/93 [==============================] - 71s 765ms/step - loss: 0.0125 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1117 - val_loss: 0.0168 - val_mean_absolute_error: 0.0974 - val_root_mean_squared_error: 0.1294 - lr: 0.0010
# Epoch 19/200
# 93/93 [==============================] - 71s 765ms/step - loss: 0.0122 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1104 - val_loss: 0.0162 - val_mean_absolute_error: 0.0958 - val_root_mean_squared_error: 0.1272 - lr: 0.0010
# Epoch 20/200
# 93/93 [==============================] - 72s 771ms/step - loss: 0.0120 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1094 - val_loss: 0.0161 - val_mean_absolute_error: 0.0955 - val_root_mean_squared_error: 0.1269 - lr: 0.0010
# Epoch 21/200
# 93/93 [==============================] - 73s 785ms/step - loss: 0.0118 - mean_absolute_error: 0.0787 - root_mean_squared_error: 0.1085 - val_loss: 0.0160 - val_mean_absolute_error: 0.0954 - val_root_mean_squared_error: 0.1265 - lr: 0.0010
# Epoch 22/200
# 93/93 [==============================] - 73s 783ms/step - loss: 0.0122 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1105 - val_loss: 0.0172 - val_mean_absolute_error: 0.0994 - val_root_mean_squared_error: 0.1310 - lr: 0.0010
# Epoch 23/200
# 93/93 [==============================] - 72s 773ms/step - loss: 0.0115 - mean_absolute_error: 0.0779 - root_mean_squared_error: 0.1071 - val_loss: 0.0157 - val_mean_absolute_error: 0.0947 - val_root_mean_squared_error: 0.1251 - lr: 0.0010
# Epoch 24/200
# 93/93 [==============================] - 72s 772ms/step - loss: 0.0114 - mean_absolute_error: 0.0775 - root_mean_squared_error: 0.1069 - val_loss: 0.0156 - val_mean_absolute_error: 0.0945 - val_root_mean_squared_error: 0.1250 - lr: 0.0010
# Epoch 25/200
# 93/93 [==============================] - 72s 774ms/step - loss: 0.0118 - mean_absolute_error: 0.0775 - root_mean_squared_error: 0.1088 - val_loss: 0.0186 - val_mean_absolute_error: 0.1033 - val_root_mean_squared_error: 0.1363 - lr: 0.0010
# Epoch 26/200
# 93/93 [==============================] - 72s 779ms/step - loss: 0.0127 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1129 - val_loss: 0.0152 - val_mean_absolute_error: 0.0932 - val_root_mean_squared_error: 0.1234 - lr: 0.0010
# Epoch 27/200
# 93/93 [==============================] - 72s 774ms/step - loss: 0.0115 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1073 - val_loss: 0.0154 - val_mean_absolute_error: 0.0935 - val_root_mean_squared_error: 0.1240 - lr: 0.0010
# Epoch 28/200
# 93/93 [==============================] - 72s 777ms/step - loss: 0.0117 - mean_absolute_error: 0.0769 - root_mean_squared_error: 0.1083 - val_loss: 0.0173 - val_mean_absolute_error: 0.1008 - val_root_mean_squared_error: 0.1316 - lr: 0.0010
# Epoch 29/200
# 93/93 [==============================] - 73s 784ms/step - loss: 0.0123 - mean_absolute_error: 0.0780 - root_mean_squared_error: 0.1107 - val_loss: 0.0233 - val_mean_absolute_error: 0.1170 - val_root_mean_squared_error: 0.1525 - lr: 0.0010
# Epoch 30/200
# 93/93 [==============================] - 73s 787ms/step - loss: 0.0122 - mean_absolute_error: 0.0786 - root_mean_squared_error: 0.1103 - val_loss: 0.0180 - val_mean_absolute_error: 0.1012 - val_root_mean_squared_error: 0.1340 - lr: 0.0010
# Epoch 31/200
# 93/93 [==============================] - 73s 787ms/step - loss: 0.0117 - mean_absolute_error: 0.0779 - root_mean_squared_error: 0.1082 - val_loss: 0.0155 - val_mean_absolute_error: 0.0944 - val_root_mean_squared_error: 0.1247 - lr: 0.0010
# Epoch 32/200
# 93/93 [==============================] - 73s 786ms/step - loss: 0.0117 - mean_absolute_error: 0.0777 - root_mean_squared_error: 0.1081 - val_loss: 0.0159 - val_mean_absolute_error: 0.0922 - val_root_mean_squared_error: 0.1261 - lr: 5.0000e-04
# Epoch 33/200
# 93/93 [==============================] - 73s 788ms/step - loss: 0.0115 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1074 - val_loss: 0.0160 - val_mean_absolute_error: 0.0924 - val_root_mean_squared_error: 0.1265 - lr: 5.0000e-04
# Epoch 34/200
# 93/93 [==============================] - 73s 786ms/step - loss: 0.0115 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1072 - val_loss: 0.0160 - val_mean_absolute_error: 0.0925 - val_root_mean_squared_error: 0.1263 - lr: 5.0000e-04
# Epoch 35/200
# 93/93 [==============================] - 71s 767ms/step - loss: 0.0115 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1074 - val_loss: 0.0162 - val_mean_absolute_error: 0.0928 - val_root_mean_squared_error: 0.1272 - lr: 5.0000e-04
# Epoch 36/200
# 93/93 [==============================] - 71s 769ms/step - loss: 0.0115 - mean_absolute_error: 0.0774 - root_mean_squared_error: 0.1072 - val_loss: 0.0159 - val_mean_absolute_error: 0.0926 - val_root_mean_squared_error: 0.1261 - lr: 5.0000e-04

# %%
single_lstm_model.save('Cruchorecasting')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa3798dac90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# See prediction on the validation set
predictions = single_lstm_model.predict(X_test)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
root_mean_absolute_error =math.sqrt(mean_squared_error)
mean_squared_error, mean_absolute_error, root_mean_absolute_error
# Out:
# (514, 864)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.015233438>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.09318805>,
#  0.12342381642948401)
